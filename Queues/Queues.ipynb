# %% [markdown]
# ## Queues in Python
# Slides - https://docs.google.com/presentation/d/1vJxxwpzwoUnnsWPT-6jDtBG4_B73eSprbzoV0V5SGNM/edit#slide=id.g1b990fde39c_1_38
#
# Real Python - https://realpython.com/queue-in-python/#queue-first-in-first-out-fifo
#
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
