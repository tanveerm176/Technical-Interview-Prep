# %% [markdown]
# ### Find K Closest Elements (Medium) [TIP103-2-2]
# - LeetCode: https://leetcode.com/problems/find-k-closest-elements/description/
# - CodePath Solution:
#
# ![image.png](attachment:image.png)
