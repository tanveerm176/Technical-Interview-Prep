# %% [markdown]
# ### Length of Longest Fibonacci (Medium) [TIP103-1-1]
# - LeetCode: https://leetcode.com/problems/length-of-longest-fibonacci-subsequence/description/
#
# ![image.png](attachment:image.png)
