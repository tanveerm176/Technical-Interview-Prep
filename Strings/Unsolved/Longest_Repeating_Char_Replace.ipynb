# %% [markdown]
# ### Longest Repeating Character Replacement (Medium) [TIP103-2-2]
# - LeetCode: https://leetcode.com/problems/longest-repeating-character-replacement/description/
# - CodePath Solution: https://guides.codepath.org/compsci/longest-repeating-character-replacement
#
# ![image.png](attachment:image.png)
