# %% [markdown]
# ### Shifting Letters (Medium) [TIP103-2-2]
# - LeetCode: https://leetcode.com/problems/shifting-letters/
# - CodePath Solution: https://guides.codepath.org/compsci/shifting-letters
#
# ![image.png](attachment:image.png)
