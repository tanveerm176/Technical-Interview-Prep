# %% [markdown]
# ### Contains Duplicates 2 (Easy) [TIP102-3-2]
# - LeetCode: https://leetcode.com/problems/contains-duplicate-ii/description/
#
# ![image.png](attachment:image.png)
