# %% [markdown]
# ### Two Sum (Easy) [TIP103-3-1]
# - LeetCode: https://leetcode.com/problems/two-sum/description/
# - CodePath Solution: https://youtu.be/CvIAdVvH1rU?list=PLrT2tZ9JRrf6E03XM-KOOu0UZPDsCmeWK&t=355
#
# ![image.png](attachment:image.png)
