# %% [markdown]
# ### Split Array into Fibonacci Sequence (Medium) [TIP103-1-1]
# - LeetCode: https://leetcode.com/problems/split-array-into-fibonacci-sequence/description/
# - Video Solution: https://youtu.be/DZRHQQ41qBU?list=PLrT2tZ9JRrf5Nelb0_Wkh_9IvgH3Y9Ad3&t=835
#
# ![image.png](attachment:image.png)
