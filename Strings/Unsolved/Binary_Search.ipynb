# %% [markdown]
# ### Binary Search (Easy) [TIP102-3-1]
# - LeetCode: https://leetcode.com/problems/binary-search/description/
# - Video: https://youtu.be/lT4m1OGmaec?list=PLrT2tZ9JRrf4cuavFcwQw6qfR8M9m7pEd&t=372
#
# ![image.png](attachment:image.png)
