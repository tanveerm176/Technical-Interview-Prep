# %% [markdown]
# ### Trapping Rain Water 2 (Hard) [TIP103-2-2]
# - LeetCode: https://leetcode.com/problems/trapping-rain-water-ii/description/
# - CodePath Solution:
#
# ![image.png](attachment:image.png)
