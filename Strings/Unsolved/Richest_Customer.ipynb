# %% [markdown]
# ### Richest Customer Wealth (Easy) [TIP102-3-2]
# - LeetCode: https://leetcode.com/problems/richest-customer-wealth/description/
#
# ![image.png](attachment:image.png)
