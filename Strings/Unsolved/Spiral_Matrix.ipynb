# %% [markdown]
# ### Spiral Matrix (Medium) [TIP103-3-1]
# - LeetCode: https://leetcode.com/problems/spiral-matrix/description/
# - CodePath Solution:
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
