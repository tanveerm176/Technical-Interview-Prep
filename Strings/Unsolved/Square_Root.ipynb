# %% [markdown]
# ### Square Root (Easy) [TIP103-3-1]
# - LeetCode: https://leetcode.com/problems/sqrtx/description/
# - CodePath Solution: https://youtu.be/CvIAdVvH1rU?list=PLrT2tZ9JRrf6E03XM-KOOu0UZPDsCmeWK&t=1271
#
# ![image.png](attachment:image.png)
