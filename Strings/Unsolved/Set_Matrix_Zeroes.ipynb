# %% [markdown]
# ### Set Matrix Zeroes (Medium) [TIP103-2-2]
# - LeetCode: https://leetcode.com/problems/set-matrix-zeroes/description/
#
# ![image.png](attachment:image.png)
