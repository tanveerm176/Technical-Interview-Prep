# %% [markdown]
# ### Int to Roman (Medium) [TIP103-1-1]
# - LeetCode: https://leetcode.com/problems/integer-to-roman/description/
# - Video Solution: https://www.youtube.com/watch?v=ohBNdSJyLh8
#
# ![image.png](attachment:image.png)
