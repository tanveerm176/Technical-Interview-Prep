# %% [markdown]
# ### Max Chunks to Make Sorted 2 (Hard) [TIP103-2-2]
# - LeetCode: https://leetcode.com/problems/max-chunks-to-make-sorted-ii/description/
# - CodePath Solution: https://youtu.be/klJKdDbTjSI?list=PLrT2tZ9JRrf6E03XM-KOOu0UZPDsCmeWK&t=745
#
# ![image-2.png](attachment:image-2.png)
