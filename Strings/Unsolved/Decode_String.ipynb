# %% [markdown]
# ### Decode String (Medium) [TIP103-1-1]
# - LeetCode: https://leetcode.com/problems/decode-string/description/
# - Video Solution: https://www.youtube.com/watch?v=E9qHRcQXmDk
#
# ![image.png](attachment:image.png)
