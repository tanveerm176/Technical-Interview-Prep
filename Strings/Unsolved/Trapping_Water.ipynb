# %% [markdown]
# ### Trapping Rain Water (Hard) [TIP103-2-2]
# - LeetCode: https://leetcode.com/problems/trapping-rain-water/description/
# - CodePath Solution:
#
# ![image.png](attachment:image.png)
