# %% [markdown]
# ### Add Binary (Easy) [TIP103-1-1]
# - LeetCode: https://leetcode.com/problems/add-binary/description/
# - Video Solution: https://www.youtube.com/watch?v=keuWJ47xG8g
#
# ![image.png](attachment:image.png)
