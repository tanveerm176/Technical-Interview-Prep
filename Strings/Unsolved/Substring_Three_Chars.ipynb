# %% [markdown]
# ### Substrings of Size Three with Distinct Characters (Easy) [TIP102-3-2]
# - LeetCode: https://leetcode.com/problems/substrings-of-size-three-with-distinct-characters/description/
#
# ![image.png](attachment:image.png)
