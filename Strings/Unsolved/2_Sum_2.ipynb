# %% [markdown]
# ### Two Sum (Easy) [TIP103-3-1]
# - LeetCode: https://leetcode.com/problems/two-sum-ii-input-array-is-sorted/description/
# - CodePath Solution: https://www.youtube.com/watch?v=cQ1Oz4ckceM&pp=ygUebGVldGNvZGUgcGFyc2UgbGlzcCBleHByZXNzaW9u
#
# ![image-2.png](attachment:image-2.png)
