# %% [markdown]
# ### Max Chunks to Make Sorted (Medium) [TIP103-2-2]
# - LeetCode: https://leetcode.com/problems/max-chunks-to-make-sorted/description/
#
# ![image.png](attachment:image.png)
