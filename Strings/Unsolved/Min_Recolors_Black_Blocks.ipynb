# %% [markdown]
# ### Minimum Recolors to Get K Consecutive Black Blocks (Easy) [TIP102-3-2]
# - LeetCode: https://leetcode.com/problems/minimum-recolors-to-get-k-consecutive-black-blocks/description/
#
# ![image.png](attachment:image.png)
