# %% [markdown]
# ### Integer Replacement (Medium) [TIP103-1-1]
# - LeetCode: https://leetcode.com/problems/integer-replacement/description/
# - CodePath Solution: https://guides.codepath.org/compsci/Integer-Replacement
# - Video Solution: https://youtu.be/DZRHQQ41qBU?list=PLrT2tZ9JRrf5Nelb0_Wkh_9IvgH3Y9Ad3&t=372
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
