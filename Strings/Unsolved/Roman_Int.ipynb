# %% [markdown]
# ### Roman to Int (Easy) [TIP103-1-1]
# - LeetCode: https://leetcode.com/problems/roman-to-integer/description/
# - Video Solution: https://www.youtube.com/watch?v=3jdxYj3DD98
#
# ![image.png](attachment:image.png)
