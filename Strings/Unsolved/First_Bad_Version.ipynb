# %% [markdown]
# ### First Bad Version (Easy) [TIP102-3-1]
# - LeetCode: https://leetcode.com/problems/first-bad-version/description/
# - Video Solution: https://youtu.be/lT4m1OGmaec?list=PLrT2tZ9JRrf4cuavFcwQw6qfR8M9m7pEd&t=2522
#
# ![image.png](attachment:image.png)
