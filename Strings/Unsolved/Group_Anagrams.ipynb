# %% [markdown]
# ### Group Anagrams (Medium) [TIP103-2-2]
# - LeetCode: https://leetcode.com/problems/group-anagrams/description/
# - CodePath Solution: https://guides.codepath.org/compsci/Group-Anagrams
#
# ![image.png](attachment:image.png)
