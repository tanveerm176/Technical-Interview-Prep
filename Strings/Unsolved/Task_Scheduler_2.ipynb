# %% [markdown]
# ### Task Scheduler 2 (Medium) [TIP103-3-1]
# - LeetCode: https://leetcode.com/problems/task-scheduler-ii/description/
# - CodePath Solution:
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
