# %% [markdown]
# ### Find Min Rotated Sorted Array (Medium) [TIP102-3-2]
# - LeetCode: https://leetcode.com/problems/find-minimum-in-rotated-sorted-array/description/
# - CodePath Solution: https://guides.codepath.org/compsci/Find-Minimum-in-Rotated-Sorted-Array
# - Video Solution: https://youtu.be/lT4m1OGmaec?list=PLrT2tZ9JRrf4cuavFcwQw6qfR8M9m7pEd&t=2812
#
# ![image.png](attachment:image.png)
