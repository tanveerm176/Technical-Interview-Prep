# %% [markdown]
# ### Valid Palindrome (Easy) [TIP103-3-1]
# - LeetCode: https://leetcode.com/problems/valid-palindrome/description/
# - Video Solution: https://youtu.be/bsjiz7t23sM?list=PLrT2tZ9JRrf4cuavFcwQw6qfR8M9m7pEd&t=2525
#
# ![image.png](attachment:image.png)
