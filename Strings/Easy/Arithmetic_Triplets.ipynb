# %% [markdown]
# ### Number of Arithmetic Triplets (Easy) [TIP103-3-1]
# - LeetCode: https://leetcode.com/problems/number-of-arithmetic-triplets/description/
#
# ![image.png](attachment:image.png)
