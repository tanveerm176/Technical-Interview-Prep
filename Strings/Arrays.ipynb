# %% [markdown]
# # Arrays in Python
# - Slides: https://docs.google.com/presentation/d/1WYjDbYgGYwOT9Pb1U1KNuU-y_i3mbnP36kNvmym8Gyo/edit#slide=id.gfee031c7e2_0_1766
# - Slides: https://docs.google.com/presentation/d/1ccg_w9vQRTLX0vt-_ZSF42zZhgiCqns335ooljOJSVw/edit#slide=id.g161e908ee94_0_142
#
#
# REAL PYTHON- https://realpython.com/python-array/
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### Two Pointer Technique
# - Slides: https://docs.google.com/presentation/d/1WYjDbYgGYwOT9Pb1U1KNuU-y_i3mbnP36kNvmym8Gyo/edit#slide=id.g1f48ec95fcd_0_155
#
# ![image.png](attachment:image.png)
