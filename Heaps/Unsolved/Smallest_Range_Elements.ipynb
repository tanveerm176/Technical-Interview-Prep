# %% [markdown]
# ####  Smallest Range Covering Elements from K Lists (Hard) [TIP103-3-2]
# - LeetCode: https://leetcode.com/problems/smallest-range-covering-elements-from-k-lists/description/
#
# ![image.png](attachment:image.png)
