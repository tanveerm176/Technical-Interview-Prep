# %% [markdown]
# #### K Largest Element (Easy) [TIP102-1-2]
# - LeetCode: https://leetcode.com/problems/kth-largest-element-in-a-stream/
# - CodePath Solution: https://guides.codepath.org/compsci/kth-largest-element-in-a-stream
#
# ![image.png](attachment:image.png)
