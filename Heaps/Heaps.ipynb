# %% [markdown]
# ## Heaps: minHeaps and maxHeaps in Python
# - CodePath Guide: https://guides.codepath.org/compsci/Heaps
#
#
# - Slides 102: https://docs.google.com/presentation/d/1vJxxwpzwoUnnsWPT-6jDtBG4_B73eSprbzoV0V5SGNM/edit#slide=id.g1b990fde39c_1_38
#
#
# - Slides 103: https://docs.google.com/presentation/d/16e083p_KUlfbjrT6daAqNnF7t-TocdwpbiV2ZEjNh_I/edit#slide=id.g212019c10b1_8_280
#
# -Real Python - https://realpython.com/python-heapq-module/
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
