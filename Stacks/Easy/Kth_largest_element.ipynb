# %% [markdown]
# #### Kth Largest Element in a Stream (Easy) [TIP102-1-2]
# - LeetCode: https://leetcode.com/problems/kth-largest-element-in-a-stream/description/
# - CodePath Solution: https://guides.codepath.org/compsci/number-of-recent-calls/
#
# ![image.png](attachment:image.png)
