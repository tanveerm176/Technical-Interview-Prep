# %% [markdown]
# #### minStack (Medium) [TIP102-1-2]
# - LeetCode: https://leetcode.com/problems/min-stack/description/
# - CodePath Solution: https://guides.codepath.org/compsci/Min-Stack
#
# ![image.png](attachment:image.png)
#
# -https://docs.google.com/presentation/d/1vJxxwpzwoUnnsWPT-6jDtBG4_B73eSprbzoV0V5SGNM/edit#slide=id.g1a7a12f983d_0_0
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)
