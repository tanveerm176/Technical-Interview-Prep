# %% [markdown]
# #### Validate Stack Sequences (Medium) [TIP102-1-2]
# - LeetCode: https://leetcode.com/problems/validate-stack-sequences/description/
# - CodePath Solution: https://guides.codepath.org/compsci/Validate-Stack-Sequences
#
# ![image.png](attachment:image.png)
