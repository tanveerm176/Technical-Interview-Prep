# %% [markdown]
# #### Implement Queue (Medium) [TIP102-1-2]
# - LeetCode: https://leetcode.com/problems/implement-queue-using-stacks/description/
# - CodePath Solution: https://youtu.be/va5zEEGPcrI?list=PLrT2tZ9JRrf6E03XM-KOOu0UZPDsCmeWK&t=3428
#
# ![image.png](attachment:image.png)
