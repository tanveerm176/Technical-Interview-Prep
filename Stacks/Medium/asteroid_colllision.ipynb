# %% [markdown]
# #### Asteroid Collision (Medium) []
# - LeetCode: https://leetcode.com/problems/asteroid-collision/description/
# - CodePath Solution: https://guides.codepath.com/compsci/Asteroid-Collision
#
# ![image.png](attachment:image.png)
