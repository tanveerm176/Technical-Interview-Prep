# %% [markdown]
# #### Basic Calculator (Medium) []
# - LeetCode: https://leetcode.com/problems/basic-calculator/description/
# - CodePath Solution: https://guides.codepath.com/compsci/Basic-Calculator
#
# ![image.png](attachment:image.png)
