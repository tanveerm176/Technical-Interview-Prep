# %% [markdown]
# ### Remove Nth Node (Medium) [TIP102-2-2]
# - LeetCode: https://leetcode.com/problems/remove-nth-node-from-end-of-list/description/
# - Video Solution:
#
# ![image.png](attachment:image.png)
