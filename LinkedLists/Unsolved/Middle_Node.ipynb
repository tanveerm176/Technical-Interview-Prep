# %% [markdown]
# ### Return Middle Node LL (Easy) [TIP102-2-2]
# - LeetCode: https://leetcode.com/problems/middle-of-the-linked-list/description/
# - Video Solution: https://www.youtube.com/watch?v=R9_-iI3wTgo&t=163s
#
# ![image.png](attachment:image.png)
