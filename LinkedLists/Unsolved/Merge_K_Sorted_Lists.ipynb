# %% [markdown]
# ### Merge K Sorted Lists (Hard) [TIP103-2-2]
# - LeetCode: https://leetcode.com/problems/merge-k-sorted-lists/description/
# - Video Solution:
#
# ![image.png](attachment:image.png)
