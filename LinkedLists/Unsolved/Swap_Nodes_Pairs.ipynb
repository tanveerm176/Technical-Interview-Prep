# %% [markdown]
# ### Swap Nodes in Pairs (Medium) [TIP102-2-2]
# - LeetCode: https://leetcode.com/problems/swap-nodes-in-pairs/description/
# - Video Solution:
#
# ![image.png](attachment:image.png)
