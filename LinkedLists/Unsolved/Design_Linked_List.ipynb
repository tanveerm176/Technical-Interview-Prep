# %% [markdown]
# ### Design Linked List (Medium) [TIP102-2-2]
# - LeetCode: https://leetcode.com/problems/design-linked-list/description/
# - Video Solution:
#
# ![image.png](attachment:image.png)
