# %% [markdown]
# ### Merge Sorted Lists (Easy) [TIP102-2-1]
# - LeetCode: https://leetcode.com/problems/merge-two-sorted-lists/description/
# - Video Solution:
#
# ![image.png](attachment:image.png)
