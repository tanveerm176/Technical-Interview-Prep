# %% [markdown]
# ### Delete Single Node (Medium) [TIP103-2-1]
# - LeetCode: https://leetcode.com/problems/delete-node-in-a-linked-list/description/
# - Video Solution: https://www.youtube.com/watch?v=d5J5MxpVrvE
#
# ![image.png](attachment:image.png)
