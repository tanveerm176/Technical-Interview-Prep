# %% [markdown]
# ### Palindrome Linked List (Easy) [TIP102-2-2]
# - LeetCode: https://leetcode.com/problems/palindrome-linked-list/description/
# - Video Solution:
#
# ![image.png](attachment:image.png)
