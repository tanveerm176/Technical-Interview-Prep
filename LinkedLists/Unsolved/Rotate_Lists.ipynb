# %% [markdown]
# ### Rotate List (Medium) [TIP103-2-2]
# - LeetCode: https://leetcode.com/problems/rotate-list/description/
# - Video Solution:
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
