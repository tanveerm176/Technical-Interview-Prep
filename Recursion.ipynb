# %% [markdown]
# # Recursion
# https://www.youtube.com/watch?v=HRPxBkkwOAg&list=PLrT2tZ9JRrf4cuavFcwQw6qfR8M9m7pEd&index=11&t=361s
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
#
# ## Recursion uses the call stack until the base case is met
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ## Recursion practice: Valid Palindrome 2 https://leetcode.com/problems/valid-palindrome-ii/
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Understand
# * Dont have to delete a letter, but if you do is the string still a palindrome?
# * Questions to ask:
#     1. Can the input string be empty?
#         * No
#     2. Is a single char a palindrome?
#         * Yes
#     3. Can the input string be a palindrome?
#         * Yes, but if it is not, it can become a palindrome through deleting one char
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Match
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### Plan
# ![image.png](attachment:image.png)
