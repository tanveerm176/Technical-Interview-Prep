# %% [markdown]
# ## HashMaps(Dictionaries) in Python
# - Slides: https://docs.google.com/presentation/d/1WYjDbYgGYwOT9Pb1U1KNuU-y_i3mbnP36kNvmym8Gyo/edit#slide=id.g1f48ec95fcd_0_195
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### Python Dictionaries (HashMap) and Functions
# - https://dbader.org/blog/python-dictionaries-maps-and-hashtables
