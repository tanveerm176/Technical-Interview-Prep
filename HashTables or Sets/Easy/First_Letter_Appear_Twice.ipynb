# %% [markdown]
# ### First Letter to Appear Twice (Easy) [TIP102-1-1]
# https://leetcode.com/problems/first-letter-to-appear-twice/
#
# ![image.png](attachment:image.png)
#
# - CodePath Solution: https://youtu.be/o4pLOa1WZEY?list=PLrT2tZ9JRrf4cuavFcwQw6qfR8M9m7pEd&t=1985
