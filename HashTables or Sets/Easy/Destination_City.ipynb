# %% [markdown]
# #### Destination City (Easy) [TIP102-1-1]
# - LeetCode: https://leetcode.com/problems/destination-city/
# - CodePath Solution: https://guides.codepath.org/compsci/Destination-City
#
# ![image.png](attachment:image.png)
