# %% [markdown]
# #### Two Sum (Easy) [TIP102-1-1]
# - LeetCode: https://leetcode.com/problems/two-sum/
# - CodePath Solution: https://guides.codepath.org/compsci/Two-Sum
#
# ![image.png](attachment:image.png)
