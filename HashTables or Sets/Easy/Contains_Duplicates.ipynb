# %% [markdown]
# #### Contains Duplicates (Easy) [TIP102-1-1]
# - LeetCode: https://leetcode.com/problems/contains-duplicate/description/
# - CodePath Solution: https://guides.codepath.org/compsci/Contains-Duplicates
#
# ![image.png](attachment:image.png)
