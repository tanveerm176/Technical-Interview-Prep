# %% [markdown]
# #### Roman to Integer (Easy) [TIP102-1-1]
# - LeetCode: https://leetcode.com/problems/roman-to-integer/
# - CodePath Solution: https://guides.codepath.org/compsci/Roman-to-Integer
#
# ![image.png](attachment:image.png)
