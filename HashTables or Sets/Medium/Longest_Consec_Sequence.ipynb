# %% [markdown]
# #### Longest Consecutive Integer (Medium) [TIP102-1-1]
# - LeetCode: https://leetcode.com/problems/longest-consecutive-sequence/
# - CodePath Solution: https://guides.codepath.org/compsci/Longest-Consecutive-Sequence
# ![image.png](attachment:image.png)
